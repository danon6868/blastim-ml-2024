# %% [markdown]
# <a href="https://colab.research.google.com/github/danon6868/blastim-ml/blob/main/statistics_day_9/%D0%9D%D0%B5%D0%B4%D0%B5%D0%BB%D1%8F_3_%D0%94%D0%B5%D0%BD%D1%8C_9_%D0%A1%D1%82%D0%B0%D1%82%D0%B8%D1%81%D1%82%D0%B8%D0%BA%D0%B0_1_%D0%9A%D0%BB%D0%B0%D1%81%D1%81.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Z-test

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
plt.rcParams["figure.figsize"] = 10, 7
plt.rcParams["font.size"] = 18

# %% [markdown]
# ## Create population

# %%
population = np.random.normal(180, 20, size=1000000)

mu = population.mean()
sigma = population.std()

print(f"mu: {mu:.3f}\tsigma: {sigma:.3f}")
# Out:
# mu: 180.034	sigma: 20.020

# %%
sns.histplot(population, stat="density");

# %% [markdown]
# ## Get the sample

# %%
sample_size = 10
sample = np.random.choice(population,
                          size=sample_size,
                          replace=False)

print(f"mean: {sample.mean():.3f}\tstd: {sample.std():.3f}")
# Out:
# mean: 185.606	std: 11.376

# %%
sns.histplot(population, stat="density")
plt.vlines(sample.mean(), ymin=0., ymax=0.02, color="red");

# %%
z_stat = (sample.mean() - mu) / (sigma / np.sqrt(sample_size))
z_stat
# Out:
# 0.8800079258872348

# %%
from scipy.stats import norm

# %%
# Если z_stat > 0, то
# p_value = 1 - norm.cdf(z_stat)
p_value = norm.cdf(z_stat)

1 - p_value
# Out:
# 0.18942750794690255

# %% [markdown]
# ## Why is z-test bad?
#
# Actually we don't know σ

# %%
def calculate_p_value_z_test(sample,
                             mu,
                             sigma=None):
    if sigma is None:
        sigma = sample.std()

    sample_size = len(sample)
    z_stat = (sample.mean() - mu) / (sigma / np.sqrt(sample_size))

    p_value = 1 - norm.cdf(z_stat)

    return p_value

# %%
# Знаем sigma
n_samples = 1000
p_values = []

for _ in range(n_samples):
    sample = np.random.choice(population,
                              size=sample_size,
                              replace=False)

    p_value = calculate_p_value_z_test(sample,
                                       mu,
                                       sigma)
    p_values.append(p_value)

p_values = np.array(p_values)

# %%
(p_values < 0.05).mean()
# Out:
# 0.062

# %%
# Не знаем sigma
n_samples = 1000
p_values = []

for _ in range(n_samples):
    sample = np.random.choice(population,
                              size=sample_size,
                              replace=False)

    p_value = calculate_p_value_z_test(sample,
                                       mu)
    p_values.append(p_value)

p_values = np.array(p_values)

# %%
(p_values < 0.05).mean()
# Out:
# 0.076

# %%
from statsmodels.stats.weightstats import ztest

# %%
ztest(sample, value=mu, alternative="two-sided")
# Out:
# (-1.5009982194160048, 0.13335602211176892)

# %%
sample.mean()
# Out:
# 168.69663362248028

# %% [markdown]
# ## Statistical power

# %%
from tqdm import tqdm

# %%
effect_size = 0.1
population_effected = population + effect_size

n_experiments = 1000
sample_size = 100
p_values = []

for _ in tqdm(range(n_experiments)):
    sample_1 = np.random.choice(population,
                                size=sample_size,
                                replace=False)

    sample_2 = np.random.choice(population_effected,
                                size=sample_size,
                                replace=False)

    _, p_value = ztest(sample_1, sample_2)
    p_values.append(p_value)

p_values = np.array(p_values)
# Out:
#   3%|█▏                                       | 30/1000 [00:01<01:01, 15.80it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_122131/4066776805.py in <module>
#      11                                 replace=False)
#      12
# ---> 13     sample_2 = np.random.choice(population_effected,
#      14                                 size=sample_size,
#      15                                 replace=False)
#
# KeyboardInterrupt:

# %%
(p_values < 0.05).mean()
# Out:
# 0.935

# %% [markdown]
# # t-test

# %%
path_to_data = "WorldHappiness_Corruption_2015_2020.csv"
data = pd.read_csv(path_to_data)
data.head()
# Out:
#        Country  happiness_score  gdp_per_capita    family    health   freedom  \
# 0       Norway            7.537        1.616463  1.533524  0.796667  0.635423
# 1      Denmark            7.522        1.482383  1.551122  0.792566  0.626007
# 2      Iceland            7.504        1.480633  1.610574  0.833552  0.627163
# 3  Switzerland            7.494        1.564980  1.516912  0.858131  0.620071
# 4      Finland            7.469        1.443572  1.540247  0.809158  0.617951
#
#    generosity  government_trust  dystopia_residual continent  Year  \
# 0    0.362012          0.315964           2.277027    Europe  2015
# 1    0.355280          0.400770           2.313707    Europe  2015
# 2    0.475540          0.153527           2.322715    Europe  2015
# 3    0.290549          0.367007           2.276716    Europe  2015
# 4    0.245483          0.382612           2.430182    Europe  2015
#
#    social_support  cpi_score
# 0             0.0         88
# 1             0.0         91
# 2             0.0         79
# 3             0.0         86
# 4             0.0         90

# %%
data.shape
# Out:
# (792, 13)

# %%
from scipy.stats import ttest_ind

# %%
ttest_ind(data.query("Country == 'Norway'")["happiness_score"],
          data.query("Country == 'Bangladesh'")["happiness_score"])
# Out:
# TtestResult(statistic=50.33951864597668, pvalue=2.3129713205961413e-13, df=10.0)

# %%
data.query("Country == 'Norway'")["happiness_score"]
# Out:
# 0      7.537
# 135    7.522
# 266    7.554
# 397    7.594
# 531    7.498
# 664    7.488
# Name: happiness_score, dtype: float64

# %%
data.query("Country == 'Bangladesh'")["happiness_score"]
# Out:
# 97     4.6080
# 223    4.6940
# 371    4.4560
# 495    4.5000
# 621    4.6430
# 755    4.8328
# Name: happiness_score, dtype: float64
